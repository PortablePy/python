# %% [markdown]
# ## Funnel Chart
#
# #### Ficitious data is used here.
# Imagine there is Food delivery App that wants to see how many people use their app to order food from **the first step i.e. Installation, Registration to ordering food.**
# Additionally, they want to look for the users who order food monthly, weeky and daily.

# %%
import pygal 
import pandas as pd

# %%
from IPython.display import display, HTML

html_skeleton = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" 
          src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
  </script>
  <script type="text/javascript" 
          src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
  </script>
  </head>
  <body>
    <figure>
      {rendered_chart}
    </figure>
  </body>
</html>
"""

def display_chart(chart):
    rendered_chart = chart.render(is_unicode=True)
    plot_html = html_skeleton.format(rendered_chart=rendered_chart)
    display(HTML(plot_html))

# %% [markdown]
# #### Custom Defined theme
#
# Theme can be custom defined using **Hex Code** and **Base style**
#
# You could just *use* **RotateStyle** and pass in the **Hex Code**

# %%
phases = ['Install', 
          'Register', 
          'Order', 
          'Monthly Order', 
          'Weekly Order', 
          'Daily Order']

# %% [markdown]
# #### Parametric Styles
# A parametric style is initiated with a default color and the other are generated from this one. The with hex code #75ff98 is a neon green

# %%
from pygal.style import RotateStyle

rotate_style = RotateStyle('#75ff98')

# %% [markdown]
# ### Initialize the object

# %%
funnel_chart = pygal.Funnel(width = 640,
                            height = 360,
                            explicit_size = True,
                            style = rotate_style)

# %%
funnel_chart.title = 'Food Delivery App Usage'

# %% [markdown]
# The steps to an order is as follows (for new registration)
# - **Install**
# - **Register/Login**
# - **Order**
#
#
# Then we go deeper by looking at users who order monthly, Weekly Order and Daily

# %%
funnel_chart.x_labels = phases

# %%
funnel_chart.add('Install', 10064)
funnel_chart.add('Register', 7473)
funnel_chart.add('Order', 6395)
funnel_chart.add('Monthly Order', 5254)
funnel_chart.add('Weekly Order', 1805)
funnel_chart.add('Daily Order', 429)

display_chart(funnel_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-835aadfa-72d2-47b6-8fc5-8a144950901f" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-05--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-835aadfa-72d2-47b6-8fc5-8a144950901f{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-835aadfa-72d2-47b6-8fc5-8a144950901f{background-color:rgba(249,249,249,1)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f path,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f line,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f rect,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .graph{fill:rgba(0,0,0,.87)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f text.no_data{fill:rgba(0,0,0,1)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .title{fill:rgba(0,0,0,1)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .legends .legend text{fill:rgba(0,0,0,.87)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis .line{stroke:rgba(0,0,0,1)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis text.major{fill:rgba(0,0,0,1)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis.y .guides:hover .guide.line,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .line-graph .axis.x .guides:hover .guide.line,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .stackedline-graph .axis.x .guides:hover .guide.line,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .ci{stroke:rgba(0,0,0,.87)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .reactive.active,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .ci .reactive.active{stroke-width:1.5}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .series text{fill:rgba(0,0,0,1)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .tooltip .label{fill:rgba(0,0,0,.87)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .tooltip .label{fill:rgba(0,0,0,.87)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .tooltip .value{font-size:1.5em}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .bound{font-size:.5em}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .color-0,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .color-0 a:visited{stroke:#75ff98;fill:#75ff98}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .color-1,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .color-1 a:visited{stroke:#75fff4;fill:#75fff4}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .color-2,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .color-2 a:visited{stroke:#75aeff;fill:#75aeff}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .color-3,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .color-3 a:visited{stroke:#9875ff;fill:#9875ff}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .color-4,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .color-4 a:visit ...
# #chart-835aadfa-72d2-47b6-8fc5-8a144950901f text.no_data{text-anchor:middle}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .guide.line{fill:none}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .centered{text-anchor:middle}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .title{text-anchor:middle}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .legends .legend text{fill-opacity:1}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis.x text{text-anchor:middle}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis.x:not(.web) text[transform]{text-anchor:start}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis.y text{text-anchor:end}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis.y text[transform].backwards{text-anchor:start}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis.y2 text{text-anchor:start}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis.y2 text[transform].backwards{text-anchor:end}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis .guide.line{stroke-dasharray:4,4}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .axis .major.guide.line{stroke-dasharray:6,6}#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .horizontal .axis.y .guide.line,#chart-835aadfa-72d2-47b6-8fc5-8a144950901f .horizontal .axis.y2 .guide.line,#chart-835aadfa-72d2-47b6-8fc5-8

# %% [markdown]
# ##### We see that, the there is huge difference between users who order monthly versus users who order daily.

# %%
funnel_chart = pygal.Funnel(width = 640,
                            height = 360,
                            explicit_size = True,
                            style = rotate_style, 
                            truncate_label = -1,
                            x_label_rotation=35,
                            range = (-6000, 6000))

# %%
funnel_chart.title = 'Food Delivery App Usage'
funnel_chart.x_labels = phases

funnel_chart.add('Install', 10064)
funnel_chart.add('Register', 7473)
funnel_chart.add('Order', 6395)
funnel_chart.add('Monthly Order', 5254)
funnel_chart.add('Weekly Order', 1805)
funnel_chart.add('Daily Order', 429)

display_chart(funnel_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-dd740159-7f68-468e-a3bb-40637d88e816" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-05--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-dd740159-7f68-468e-a3bb-40637d88e816{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-dd740159-7f68-468e-a3bb-40637d88e816 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-dd740159-7f68-468e-a3bb-40637d88e816{background-color:rgba(249,249,249,1)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 path,#chart-dd740159-7f68-468e-a3bb-40637d88e816 line,#chart-dd740159-7f68-468e-a3bb-40637d88e816 rect,#chart-dd740159-7f68-468e-a3bb-40637d88e816 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .graph{fill:rgba(0,0,0,.87)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 text.no_data{fill:rgba(0,0,0,1)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .title{fill:rgba(0,0,0,1)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis .line{stroke:rgba(0,0,0,1)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis text.major{fill:rgba(0,0,0,1)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis.y .guides:hover .guide.line,#chart-dd740159-7f68-468e-a3bb-40637d88e816 .line-graph .axis.x .guides:hover .guide.line,#chart-dd740159-7f68-468e-a3bb-40637d88e816 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-dd740159-7f68-468e-a3bb-40637d88e816 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .ci{stroke:rgba(0,0,0,.87)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .reactive.active,#chart-dd740159-7f68-468e-a3bb-40637d88e816 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .ci .reactive.active{stroke-width:1.5}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .series text{fill:rgba(0,0,0,1)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .tooltip .value{font-size:1.5em}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .bound{font-size:.5em}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .color-0,#chart-dd740159-7f68-468e-a3bb-40637d88e816 .color-0 a:visited{stroke:#75ff98;fill:#75ff98}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .color-1,#chart-dd740159-7f68-468e-a3bb-40637d88e816 .color-1 a:visited{stroke:#75fff4;fill:#75fff4}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .color-2,#chart-dd740159-7f68-468e-a3bb-40637d88e816 .color-2 a:visited{stroke:#75aeff;fill:#75aeff}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .color-3,#chart-dd740159-7f68-468e-a3bb-40637d88e816 .color-3 a:visited{stroke:#9875ff;fill:#9875ff}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .color-4,#chart-dd740159-7f68-468e-a3bb-40637d88e816 .color-4 a:visit ...
# #chart-dd740159-7f68-468e-a3bb-40637d88e816 text.no_data{text-anchor:middle}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .guide.line{fill:none}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .centered{text-anchor:middle}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .title{text-anchor:middle}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .legends .legend text{fill-opacity:1}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis.x text{text-anchor:middle}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis.y text{text-anchor:end}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis.y text[transform].backwards{text-anchor:start}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis.y2 text{text-anchor:start}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis.y2 text[transform].backwards{text-anchor:end}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis .guide.line{stroke-dasharray:4,4}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .axis .major.guide.line{stroke-dasharray:6,6}#chart-dd740159-7f68-468e-a3bb-40637d88e816 .horizontal .axis.y .guide.line,#chart-dd740159-7f68-468e-a3bb-40637d88e816 .horizontal .axis.y2 .guide.line,#chart-dd740159-7f68-468e-a3bb-4

# %%
from pygal.style import DarkenStyle

# %%
darken_style = DarkenStyle('#75ff98', step = 5)

# %%
funnel_chart = pygal.Funnel(width = 640,
                            height = 360,
                            explicit_size = True,
                            style = darken_style, 
                            truncate_label = -1,
                            x_label_rotation=35,
                            range = (-6000, 6000))

# %%
funnel_chart.title = 'Food Delivery App Usage'
funnel_chart.x_labels = phases

funnel_chart.add('Install', 10064)
funnel_chart.add('Register', 7473)
funnel_chart.add('Order', 6395)
funnel_chart.add('Monthly Order', 5254)
funnel_chart.add('Weekly Order', 1805)
funnel_chart.add('Daily Order', 429)

display_chart(funnel_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-05--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6{background-color:rgba(249,249,249,1)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 path,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 line,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 rect,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .graph{fill:rgba(0,0,0,.87)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 text.no_data{fill:rgba(0,0,0,1)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .title{fill:rgba(0,0,0,1)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis .line{stroke:rgba(0,0,0,1)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis text.major{fill:rgba(0,0,0,1)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis.y .guides:hover .guide.line,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .line-graph .axis.x .guides:hover .guide.line,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .ci{stroke:rgba(0,0,0,.87)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .reactive.active,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .ci .reactive.active{stroke-width:1.5}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .series text{fill:rgba(0,0,0,1)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .tooltip .value{font-size:1.5em}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .bound{font-size:.5em}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .color-0,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .color-0 a:visited{stroke:#75ff98;fill:#75ff98}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .color-1,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .color-1 a:visited{stroke:#35ff68;fill:#35ff68}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .color-2,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .color-2 a:visited{stroke:#00f43e;fill:#00f43e}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .color-3,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .color-3 a:visited{stroke:#00b52e;fill:#00b52e}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .color-4,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .color-4 a:visit ...
# #chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 text.no_data{text-anchor:middle}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .guide.line{fill:none}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .centered{text-anchor:middle}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .title{text-anchor:middle}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .legends .legend text{fill-opacity:1}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis.x text{text-anchor:middle}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis.y text{text-anchor:end}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis.y text[transform].backwards{text-anchor:start}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis.y2 text{text-anchor:start}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis.y2 text[transform].backwards{text-anchor:end}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis .guide.line{stroke-dasharray:4,4}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .axis .major.guide.line{stroke-dasharray:6,6}#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .horizontal .axis.y .guide.line,#chart-5d853f98-5795-4f50-b1ee-5dfaeac60fb6 .horizontal .axis.y2 .guide.line,#chart-5d853f98-5795-4f50-b1ee-5
