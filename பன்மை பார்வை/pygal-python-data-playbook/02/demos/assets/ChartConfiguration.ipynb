# %% [markdown]
# ## Bar Chart Configuration
#
# In this demo we will be using **Serie Configuration** i.e Options can be customized every time when data is added.
# Serie Configuration can be applied to any graph while adding to the data.
#
# Here, Bar graph is used to demonstrate the *configuration*

# %%
import pygal
from IPython.display import display, HTML

# %% [markdown]
# Method to display the **interactive graph** in Jupyter notebook. The method defined below takes in the **html code** and the **rendered chart**, inserts the chart into html code to display the chart with interactive graphics.

# %%
html_skeleton = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" 
          src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
  </script>
  <script type="text/javascript" 
          src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
  </script>
  </head>
  <body>
    <figure>
      {rendered_chart}
    </figure>
  </body>
</html>
"""

def display_chart(chart):
    rendered_chart = chart.render(is_unicode=True)
    plot_html = html_skeleton.format(rendered_chart=rendered_chart)
    display(HTML(plot_html))

# %%
bar_chart = pygal.Bar(width = 640,
                      height = 360,
                      explicit_size = True)

# %%
bar_chart.title = "Pet Population By Animal Per 100 households"

# %%
display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-77a1009a-fcfc-4c72-b028-7350eef696cf" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-77a1009a-fcfc-4c72-b028-7350eef696cf{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-77a1009a-fcfc-4c72-b028-7350eef696cf{background-color:rgba(249,249,249,1)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf path,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf line,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf rect,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .graph{fill:rgba(0,0,0,.87)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf text.no_data{fill:rgba(0,0,0,1)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .title{fill:rgba(0,0,0,1)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .legends .legend text{fill:rgba(0,0,0,.87)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis .line{stroke:rgba(0,0,0,1)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis text.major{fill:rgba(0,0,0,1)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis.y .guides:hover .guide.line,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .line-graph .axis.x .guides:hover .guide.line,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .stackedline-graph .axis.x .guides:hover .guide.line,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .ci{stroke:rgba(0,0,0,.87)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .reactive.active,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .ci .reactive.active{stroke-width:1.5}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .series text{fill:rgba(0,0,0,1)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .tooltip .label{fill:rgba(0,0,0,.87)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .tooltip .label{fill:rgba(0,0,0,.87)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .tooltip .value{font-size:1.5em}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .bound{font-size:.5em}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}
# #chart-77a1009a-fcfc-4c72-b028-7350eef696cf text.no_data{text-anchor:middle}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .guide.line{fill:none}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .centered{text-anchor:middle}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .title{text-anchor:middle}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .legends .legend text{fill-opacity:1}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis.x text{text-anchor:middle}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis.x:not(.web) text[transform]{text-anchor:start}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis.y text{text-anchor:end}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis.y text[transform].backwards{text-anchor:start}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis.y2 text{text-anchor:start}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis.y2 text[transform].backwards{text-anchor:end}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis .guide.line{stroke-dasharray:4,4}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis .major.guide.line{stroke-dasharray:6,6}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .horizontal .axis.y .guide.line,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .horizontal .axis.y2 .guide.line,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .vertical .axis.x .guide.line{opacity:0}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .horizontal .axis.always_show .guide.line,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis.y .guides:hover .guide.line,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis.y2 .guides:hover .guide.line,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis.x .guides:hover .guide.line{opacity:1}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .axis .guides:hover text{opacity:1}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .nofill{fill:none}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .subtle-fill{fill-opacity:.2}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .dot{stroke-width:1px;fill-opacity:1}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .dot.active{stroke-width:5px}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .dot.negative{fill:transparent}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf text,#chart-77a1009a-fcfc-4c72-b028-7350eef696cf tspan{stroke:none !important}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .series text.active{opacity:1}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .tooltip rect{fill-opacity:.95;stroke-width:.5}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .tooltip text{fill-opacity:1}#chart-77a1009a-fcfc-4c72-b028-7350eef696cf .showable{visibility:hidden

# %%
bar_chart = pygal.Bar(width = 640,
                      height = 360,
                      explicit_size = True, 
                      no_data_text = 'Data Missing :(')

# %%
bar_chart.title = "Pet Population By Animal Per 100 households"
display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-76275704-34da-4a1f-bcc1-138529f0d6a6" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-76275704-34da-4a1f-bcc1-138529f0d6a6{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-76275704-34da-4a1f-bcc1-138529f0d6a6{background-color:rgba(249,249,249,1)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 path,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 line,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 rect,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .graph{fill:rgba(0,0,0,.87)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 text.no_data{fill:rgba(0,0,0,1)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .title{fill:rgba(0,0,0,1)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis .line{stroke:rgba(0,0,0,1)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis text.major{fill:rgba(0,0,0,1)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis.y .guides:hover .guide.line,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .line-graph .axis.x .guides:hover .guide.line,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .ci{stroke:rgba(0,0,0,.87)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .reactive.active,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .ci .reactive.active{stroke-width:1.5}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .series text{fill:rgba(0,0,0,1)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .tooltip .value{font-size:1.5em}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .bound{font-size:.5em}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}
# #chart-76275704-34da-4a1f-bcc1-138529f0d6a6 text.no_data{text-anchor:middle}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .guide.line{fill:none}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .centered{text-anchor:middle}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .title{text-anchor:middle}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .legends .legend text{fill-opacity:1}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis.x text{text-anchor:middle}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis.y text{text-anchor:end}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis.y text[transform].backwards{text-anchor:start}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis.y2 text{text-anchor:start}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis.y2 text[transform].backwards{text-anchor:end}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis .guide.line{stroke-dasharray:4,4}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis .major.guide.line{stroke-dasharray:6,6}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .horizontal .axis.y .guide.line,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .horizontal .axis.y2 .guide.line,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .vertical .axis.x .guide.line{opacity:0}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .horizontal .axis.always_show .guide.line,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis.y .guides:hover .guide.line,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis.y2 .guides:hover .guide.line,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis.x .guides:hover .guide.line{opacity:1}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .axis .guides:hover text{opacity:1}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .nofill{fill:none}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .subtle-fill{fill-opacity:.2}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .dot{stroke-width:1px;fill-opacity:1}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .dot.active{stroke-width:5px}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .dot.negative{fill:transparent}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 text,#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 tspan{stroke:none !important}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .series text.active{opacity:1}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .tooltip rect{fill-opacity:.95;stroke-width:.5}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .tooltip text{fill-opacity:1}#chart-76275704-34da-4a1f-bcc1-138529f0d6a6 .showable{visibility:hidden

# %% [markdown]
# Initialize the bar chart object and pass in the parameter **print_vales=True** which will print the values on the bar chart.

# %%
bar_chart = pygal.Bar(width = 640,
                      height = 360,
                      explicit_size = True,
                      no_data_text = 'Data Missing :(',
                      print_values=True)

bar_chart.title = "Pet Population By Animal Per 100 households"

# %% [markdown]
# Add in the data to the chart and notice that we have passed in the parameter **rounded_bars** which will **round the edges of the bars** Then pass in the chart to **display_chart** method to display the interactive chart.

# %%
bar_chart.add('Dogs', 41, 
              rounded_bars = 10)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-d35a514e-69ec-48cc-9849-732a12b8b86b" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-d35a514e-69ec-48cc-9849-732a12b8b86b{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-d35a514e-69ec-48cc-9849-732a12b8b86b{background-color:rgba(249,249,249,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b path,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b rect,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .graph{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .line{stroke:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text.major{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .line-graph .axis.x .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .stackedline-graph .axis.x .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .ci{stroke:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .reactive.active,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .ci .reactive.active{stroke-width:1.5}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .series text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .value{font-size:1.5em}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .bound{font-size:.5em}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-0,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay .color-0 text{fill:black}
# #chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .guide.line{fill:none}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .centered{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{fill-opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x text{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x:not(.web) text[transform]{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y text{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y text[transform].backwards{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 text{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 text[transform].backwards{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guide.line{stroke-dasharray:4,4}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .major.guide.line{stroke-dasharray:6,6}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.y .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.y2 .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .vertical .axis.x .guide.line{opacity:0}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.always_show .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x .guides:hover .guide.line{opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guides:hover text{opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .nofill{fill:none}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .subtle-fill{fill-opacity:.2}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .dot{stroke-width:1px;fill-opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .dot.active{stroke-width:5px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .dot.negative{fill:transparent}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b tspan{stroke:none !important}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .series text.active{opacity:1}#chart-d

# %% [markdown]
# We can pass in the individual **formatter** to format the individual bar.

# %%
bar_chart.add('Cats', 20, 
              rounded_bars = 50, 
              formatter = lambda x: '%s Cats' % x)
display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-d35a514e-69ec-48cc-9849-732a12b8b86b" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-d35a514e-69ec-48cc-9849-732a12b8b86b{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-d35a514e-69ec-48cc-9849-732a12b8b86b{background-color:rgba(249,249,249,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b path,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b rect,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .graph{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .line{stroke:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text.major{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .line-graph .axis.x .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .stackedline-graph .axis.x .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .ci{stroke:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .reactive.active,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .ci .reactive.active{stroke-width:1.5}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .series text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .value{font-size:1.5em}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .bound{font-size:.5em}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-0,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-1,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay .color-0 text{fill:black}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay .color-1 text{fill:black}
# #chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .guide.line{fill:none}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .centered{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{fill-opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x text{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x:not(.web) text[transform]{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y text{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y text[transform].backwards{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 text{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 text[transform].backwards{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guide.line{stroke-dasharray:4,4}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .major.guide.line{stroke-dasharray:6,6}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.y .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.y2 .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .vertical .axis.x .guide.line{opacity:0}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.always_show .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x .guides:hover .guide.line{opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guides:hover text{opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .nofill{fill:none}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .subtle-fill{fill-opacity:.2}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .dot{stroke-width:1px;fill-opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .dot.active{stroke-width:5px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .dot.neg

# %% [markdown]
# You can pass in the style like the **fill**, **stroke** color and **stroke-width**

# %%
bar_chart.add('Birds', 
              [{'value': 12, 
                'style': 'fill: green; stroke: black; stroke-width: 4'}])

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-d35a514e-69ec-48cc-9849-732a12b8b86b" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-d35a514e-69ec-48cc-9849-732a12b8b86b{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-d35a514e-69ec-48cc-9849-732a12b8b86b{background-color:rgba(249,249,249,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b path,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b rect,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .graph{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .line{stroke:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text.major{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .line-graph .axis.x .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .stackedline-graph .axis.x .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .ci{stroke:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .reactive.active,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .ci .reactive.active{stroke-width:1.5}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .series text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .value{font-size:1.5em}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .bound{font-size:.5em}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-0,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-1,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-2,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-2 a:visited{stroke:#009688;fill:#009688}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay .color-0 text{fill:black}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay .color-1 text{fill:black}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay .color-2 text{fill:black}
# #chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .guide.line{fill:none}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .centered{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{fill-opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x text{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x:not(.web) text[transform]{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y text{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y text[transform].backwards{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 text{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 text[transform].backwards{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guide.line{stroke-dasharray:4,4}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .major.guide.line{stroke-dasharray:6,6}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.y .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.y2 .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .vertical .axis.x .guide.line{opacity:0}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.always_show .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x .guides:hover .guide.line{opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guides:hover text{opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .nofill{fill:none}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .subtle-

# %% [markdown]
# Embed a **link** in the bar, when you hover over the bar plotted. You can define the link using **xlink** field notice, the values passed in a dictionary inside a list.
#
# When you hover over the **horse** you can see the link embedded. Link takes you to adopt a hourse to bluecross pet website.

# %%
bar_chart.add('Horses', 
              [{'value': 7,
                'xlink': 'https://www.bluecross.org.uk/rehome/horse'}])

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-d35a514e-69ec-48cc-9849-732a12b8b86b" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-d35a514e-69ec-48cc-9849-732a12b8b86b{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-d35a514e-69ec-48cc-9849-732a12b8b86b{background-color:rgba(249,249,249,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b path,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b rect,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .graph{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .line{stroke:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text.major{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .line-graph .axis.x .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .stackedline-graph .axis.x .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .ci{stroke:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .reactive.active,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .ci .reactive.active{stroke-width:1.5}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .series text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .value{font-size:1.5em}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .bound{font-size:.5em}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-0,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-1,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-2,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-2 a:visited{stroke:#009688;fill:#009688}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-3,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay .color-0 text{fill:black}#chart-d35a514e-69ec-48cc-9849 ...
# #chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .guide.line{fill:none}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .centered{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{fill-opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x text{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x:not(.web) text[transform]{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y text{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y text[transform].backwards{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 text{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 text[transform].backwards{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guide.line{stroke-dasharray:4,4}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .major.guide.line{stroke-dasharray:6,6}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.y .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.y2 .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .vertical .axis.x .guide.line{opacity:0}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.always_show .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x .g

# %% [markdown]
# You can change the **color** of the bar using **color** field passed in dictionary. Here we are changing the color of the **Exotic pets** to **Maroon**, just to distinguish between other bars regardless of the legend.

# %%
bar_chart.add('Exotic Pets', 
              [{'value': 2, 
                'color': 'maroon'}])

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-d35a514e-69ec-48cc-9849-732a12b8b86b" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-d35a514e-69ec-48cc-9849-732a12b8b86b{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-d35a514e-69ec-48cc-9849-732a12b8b86b{background-color:rgba(249,249,249,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b path,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b rect,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .graph{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .line{stroke:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text.major{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .line-graph .axis.x .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .stackedline-graph .axis.x .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .ci{stroke:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .reactive.active,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .ci .reactive.active{stroke-width:1.5}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .series text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .value{font-size:1.5em}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .bound{font-size:.5em}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-0,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-1,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-2,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-2 a:visited{stroke:#009688;fill:#009688}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-3,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-4,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-4 a:visit ...
# #chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .guide.line{fill:none}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .centered{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{fill-opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x text{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x:not(.web) text[transform]{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y text{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y text[transform].backwards{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 text{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 text[transform].backwards{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guide.line{stroke-dasharray:4,4}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .major.guide.line{stroke-dasharray:6,6}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.y .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.y2 .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .vertical .axis.x .guide.line{opacity:0}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.always_show .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .vertical .axis.always_show .guide.line{opaci

# %% [markdown]
# You can add a link to the **legend of bar**. Here, **we are adding a link to bluecross pet website to adopt a pet.**

# %%
bar_chart.add({'title': 'No Pets',
               'xlink': {'href': 'https://www.bluecross.org.uk/rehome-pet'}
              }, 
              18)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-d35a514e-69ec-48cc-9849-732a12b8b86b" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-d35a514e-69ec-48cc-9849-732a12b8b86b{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-d35a514e-69ec-48cc-9849-732a12b8b86b{background-color:rgba(249,249,249,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b path,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b rect,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .graph{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .line{stroke:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis text.major{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .line-graph .axis.x .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .stackedline-graph .axis.x .guides:hover .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .ci{stroke:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .reactive.active,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .ci .reactive.active{stroke-width:1.5}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .series text{fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .tooltip .value{font-size:1.5em}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .bound{font-size:.5em}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-0,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-1,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-2,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-2 a:visited{stroke:#009688;fill:#009688}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-3,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-4,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .color-4 a:visit ...
# #chart-d35a514e-69ec-48cc-9849-732a12b8b86b text.no_data{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .guide.line{fill:none}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .centered{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .title{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .legends .legend text{fill-opacity:1}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x text{text-anchor:middle}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x:not(.web) text[transform]{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y text{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y text[transform].backwards{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 text{text-anchor:start}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis.y2 text[transform].backwards{text-anchor:end}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .guide.line{stroke-dasharray:4,4}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .axis .major.guide.line{stroke-dasharray:6,6}#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.y .guide.line,#chart-d35a514e-69ec-48cc-9849-732a12b8b86b .horizontal .axis.y2 .guide.line,#chart-d35a514e-69ec-48cc-9849-7

# %%
from pygal.style import DarkStyle

# %%
bar_chart = pygal.Bar(width = 640,
                      height = 360,
                      explicit_size = True)

# %%
bar_chart.style = DarkStyle

# %%
bar_chart.add('Dogs', 41)
bar_chart.add('Cats', 20)
bar_chart.add('Bird', 12)
bar_chart.add('Horses', 7)
bar_chart.add('Exotic Pets', 2)
bar_chart.add('No Pets', 18)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-9837c702-cb35-4a5d-9c46-d329ea741fc2" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-9837c702-cb35-4a5d-9c46-d329ea741fc2{background-color:black}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 path,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 line,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 rect,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .graph &gt; .background{fill:black}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .plot &gt; .background{fill:#111}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .graph{fill:#999}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 text.no_data{fill:#eee}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .title{fill:#eee}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .legends .legend text{fill:#999}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .legends .legend:hover text{fill:#eee}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis .line{stroke:#eee}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis .guide.line{stroke:#555}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis .major.line{stroke:#999}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis text.major{fill:#eee}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis.y .guides:hover .guide.line,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .line-graph .axis.x .guides:hover .guide.line,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis .guides:hover text{fill:#eee}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .reactive{fill-opacity:.8;stroke-opacity:.8}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .ci{stroke:#999}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .reactive.active,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .active .reactive{fill-opacity:.4;stroke-opacity:.9;stroke-width:4}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .ci .reactive.active{stroke-width:1.5}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .series text{fill:#eee}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .tooltip rect{fill:#111;stroke:#eee;-webkit-transition:opacity 250ms;-moz-transition:opacity 250ms;transition:opacity 250ms}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .tooltip .label{fill:#999}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .tooltip .label{fill:#999}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .tooltip .legend{font-size:.8em;fill:#555}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .tooltip .x_label{font-size:.6em;fill:#eee}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .tooltip .value{font-size:1.5em}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .bound{font-size:.5em}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .max-value{font-size:.75em;fill:#555}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .map-element{fill:#111;stroke:#555 !important}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .color-0,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .color-0 a:visited{stroke:#ff5995;fill:#ff5995}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .color-1,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .color-1 a:visited{stroke:#b6e354;fill:#b6e354}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .color-2,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .color-2 a:visited{stroke:#feed6c;fill:#feed6c}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .color-3,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .color-3 a:visited{stroke:#8cedff;fill:#8cedff}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .color-4,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .color-4 a:visited{stroke:#9e6ffe;fill:#9e6ffe}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .color-5,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .color-5 a:visited{stroke:#899ca1;fill:#899ca1}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .text-overlay .color-0 text{fill:black}#chart-9837c702 ...
# #chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 text.no_data{text-anchor:middle}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .guide.line{fill:none}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .centered{text-anchor:middle}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .title{text-anchor:middle}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .legends .legend text{fill-opacity:1}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis.x text{text-anchor:middle}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis.y text{text-anchor:end}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis.y text[transform].backwards{text-anchor:start}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis.y2 text{text-anchor:start}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis.y2 text[transform].backwards{text-anchor:end}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis .guide.line{stroke-dasharray:4,4}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .axis .major.guide.line{stroke-dasharray:6,6}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .horizontal .axis.y .guide.line,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .horizontal .axis.y2 .guide.line,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .vertical .axis.x .guide.line{opacity:0}#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .horizontal .axis.always_show .guide.line,#chart-9837c702-cb35-4a5d-9c46-d329ea741fc2 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-9837c702-cb35-4a5d-9c46

# %% [markdown]
# #### Parametric Styles

# %%
from pygal.style import DarkenStyle

# %%
darken_style = DarkenStyle('#75FFFD')

# %%
bar_chart = pygal.Bar(width = 640,
                      height = 360,
                      explicit_size = True, 
                      style = darken_style)

# %%
bar_chart.add('Dogs', 41)
bar_chart.add('Cats', 20)
bar_chart.add('Bird', 12)
bar_chart.add('Horses', 7)
bar_chart.add('Exotic Pets', 2)
bar_chart.add('No Pets', 18)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-54b04005-d44d-4a10-84cd-43c318686ffd" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-54b04005-d44d-4a10-84cd-43c318686ffd{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-54b04005-d44d-4a10-84cd-43c318686ffd{background-color:rgba(249,249,249,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd path,#chart-54b04005-d44d-4a10-84cd-43c318686ffd line,#chart-54b04005-d44d-4a10-84cd-43c318686ffd rect,#chart-54b04005-d44d-4a10-84cd-43c318686ffd circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .graph{fill:rgba(0,0,0,.87)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd text.no_data{fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .title{fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .legends .legend text{fill:rgba(0,0,0,.87)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis .line{stroke:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis text.major{fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.y .guides:hover .guide.line,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .line-graph .axis.x .guides:hover .guide.line,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .stackedline-graph .axis.x .guides:hover .guide.line,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .ci{stroke:rgba(0,0,0,.87)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .reactive.active,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .ci .reactive.active{stroke-width:1.5}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .series text{fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip .label{fill:rgba(0,0,0,.87)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip .label{fill:rgba(0,0,0,.87)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip .value{font-size:1.5em}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .bound{font-size:.5em}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-0,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-0 a:visited{stroke:#75fffd;fill:#75fffd}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-1,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-1 a:visited{stroke:#59fffd;fill:#59fffd}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-2,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-2 a:visited{stroke:#3cfffc;fill:#3cfffc}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-3,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-3 a:visited{stroke:#20fffc;fill:#20fffc}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-4,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-4 a:visit ...
# #chart-54b04005-d44d-4a10-84cd-43c318686ffd text.no_data{text-anchor:middle}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .guide.line{fill:none}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .centered{text-anchor:middle}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .title{text-anchor:middle}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .legends .legend text{fill-opacity:1}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.x text{text-anchor:middle}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.x:not(.web) text[transform]{text-anchor:start}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.y text{text-anchor:end}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.y text[transform].backwards{text-anchor:start}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.y2 text{text-anchor:start}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.y2 text[transform].backwards{text-anchor:end}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis .guide.line{stroke-dasharray:4,4}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis .major.guide.line{stroke-dasharray:6,6}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .horizontal .axis.y .guide.line,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .horizontal .axis.y2 .guide.line,#chart-54b04005-d44d-4a10-84cd-4

# %%
bar_chart.style = DarkenStyle('#75FFFD', 
                              step = 5)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-54b04005-d44d-4a10-84cd-43c318686ffd" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-54b04005-d44d-4a10-84cd-43c318686ffd{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-54b04005-d44d-4a10-84cd-43c318686ffd text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-54b04005-d44d-4a10-84cd-43c318686ffd{background-color:rgba(249,249,249,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd path,#chart-54b04005-d44d-4a10-84cd-43c318686ffd line,#chart-54b04005-d44d-4a10-84cd-43c318686ffd rect,#chart-54b04005-d44d-4a10-84cd-43c318686ffd circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .graph{fill:rgba(0,0,0,.87)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd text.no_data{fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .title{fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .legends .legend text{fill:rgba(0,0,0,.87)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis .line{stroke:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis text.major{fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.y .guides:hover .guide.line,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .line-graph .axis.x .guides:hover .guide.line,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .stackedline-graph .axis.x .guides:hover .guide.line,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .ci{stroke:rgba(0,0,0,.87)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .reactive.active,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .ci .reactive.active{stroke-width:1.5}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .series text{fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip .label{fill:rgba(0,0,0,.87)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip .label{fill:rgba(0,0,0,.87)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .tooltip .value{font-size:1.5em}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .bound{font-size:.5em}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-0,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-0 a:visited{stroke:#75fffd;fill:#75fffd}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-1,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-1 a:visited{stroke:#35fffc;fill:#35fffc}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-2,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-2 a:visited{stroke:#00f4f1;fill:#00f4f1}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-3,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-3 a:visited{stroke:#00b5b2;fill:#00b5b2}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-4,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .color-4 a:visit ...
# #chart-54b04005-d44d-4a10-84cd-43c318686ffd text.no_data{text-anchor:middle}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .guide.line{fill:none}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .centered{text-anchor:middle}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .title{text-anchor:middle}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .legends .legend text{fill-opacity:1}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.x text{text-anchor:middle}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.x:not(.web) text[transform]{text-anchor:start}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.y text{text-anchor:end}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.y text[transform].backwards{text-anchor:start}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.y2 text{text-anchor:start}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis.y2 text[transform].backwards{text-anchor:end}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis .guide.line{stroke-dasharray:4,4}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .axis .major.guide.line{stroke-dasharray:6,6}#chart-54b04005-d44d-4a10-84cd-43c318686ffd .horizontal .axis.y .guide.line,#chart-54b04005-d44d-4a10-84cd-43c318686ffd .horizontal .axis.y2 .guide.line,#chart-54b04005-d44d-4a10-84cd-4

# %%
from pygal.style import Style

# %%
custom_style = Style(background='#ECF2F2',
                     plot_background='transparent',
                     opacity='.6',
                     transition='400ms ease-in',
                     legend_font_family = 'arial',
                     legend_font_size = 12,
                     colors=('red', '#8299F7', 
                             '#ED8223', 'purple', 
                             '#E89B53', 'deeppink'))

# %%
bar_chart = pygal.Bar(width = 640,
                      height = 360,
                      explicit_size = True, 
                      style = custom_style)

# %%
bar_chart.add('Dogs', 41)
bar_chart.add('Cats', 20)
bar_chart.add('Bird', 12)
bar_chart.add('Horses', 7)
bar_chart.add('Exotic Pets', 2)
bar_chart.add('No Pets', 18)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .legends .legend text{font-family:arial;font-size:12px}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d{background-color:#ECF2F2}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d path,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d line,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d rect,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d circle{-webkit-transition:400ms ease-in;-moz-transition:400ms ease-in;transition:400ms ease-in}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .graph &gt; .background{fill:#ECF2F2}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .plot &gt; .background{fill:transparent}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .graph{fill:rgba(0,0,0,.87)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d text.no_data{fill:rgba(0,0,0,1)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .title{fill:rgba(0,0,0,1)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .legends .legend text{fill:rgba(0,0,0,.87)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis .line{stroke:rgba(0,0,0,1)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis text.major{fill:rgba(0,0,0,1)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis.y .guides:hover .guide.line,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .line-graph .axis.x .guides:hover .guide.line,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .stackedline-graph .axis.x .guides:hover .guide.line,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .reactive{fill-opacity:.6;stroke-opacity:.8}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .ci{stroke:rgba(0,0,0,.87)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .reactive.active,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .ci .reactive.active{stroke-width:1.5}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .series text{fill:rgba(0,0,0,1)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .tooltip rect{fill:transparent;stroke:rgba(0,0,0,1);-webkit-transition:opacity 400ms ease-in;-moz-transition:opacity 400ms ease-in;transition:opacity 400ms ease-in}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .tooltip .label{fill:rgba(0,0,0,.87)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .tooltip .label{fill:rgba(0,0,0,.87)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .tooltip .value{font-size:1.5em}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .bound{font-size:.5em}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .map-element{fill:transparent;stroke:rgba(0,0,0,.54) !important}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .color-0,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .color-0 a:visited{stroke:red;fill:red}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .color-1,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .color-1 a:visited{stroke:#8299F7;fill:#8299F7}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .color-2,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .color-2 a:visited{stroke:#ED8223;fill:#ED8223}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .color-3,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .color-3 a:visited{stroke:purple;fill:purple}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .color-4,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .color-4 a:visited{stroke: ...
# #chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d text.no_data{text-anchor:middle}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .guide.line{fill:none}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .centered{text-anchor:middle}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .title{text-anchor:middle}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .legends .legend text{fill-opacity:1}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis.x text{text-anchor:middle}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis.x:not(.web) text[transform]{text-anchor:start}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis.y text{text-anchor:end}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis.y text[transform].backwards{text-anchor:start}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis.y2 text{text-anchor:start}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis.y2 text[transform].backwards{text-anchor:end}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis .guide.line{stroke-dasharray:4,4}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .axis .major.guide.line{stroke-dasharray:6,6}#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .horizontal .axis.y .guide.line,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .horizontal .axis.y2 .guide.line,#chart-3ece3bc7-17d7-4e26-a4cd-b8003743c76d .vertical .axis.x .guide.line{opacity:0}#

# %%
from pygal import Config

# %%
custom_config = Config(width = 640,
                       height = 360,
                       explicit_size = True, 
                       style = custom_style)

# %%
bar_chart = pygal.Bar(config = custom_config)

# %%
bar_chart.add('Dogs', 41)
bar_chart.add('Cats', 20)
bar_chart.add('Bird', 12)
bar_chart.add('Horses', 7)
bar_chart.add('Exotic Pets', 2)
bar_chart.add('No Pets', 18)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-e8f3680e-a952-4c25-b976-ab59c5c654b5" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .legends .legend text{font-family:arial;font-size:12px}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-e8f3680e-a952-4c25-b976-ab59c5c654b5{background-color:#ECF2F2}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 path,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 line,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 rect,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 circle{-webkit-transition:400ms ease-in;-moz-transition:400ms ease-in;transition:400ms ease-in}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .graph &gt; .background{fill:#ECF2F2}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .plot &gt; .background{fill:transparent}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .graph{fill:rgba(0,0,0,.87)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 text.no_data{fill:rgba(0,0,0,1)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .title{fill:rgba(0,0,0,1)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis .line{stroke:rgba(0,0,0,1)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis text.major{fill:rgba(0,0,0,1)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis.y .guides:hover .guide.line,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .line-graph .axis.x .guides:hover .guide.line,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .reactive{fill-opacity:.6;stroke-opacity:.8}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .ci{stroke:rgba(0,0,0,.87)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .reactive.active,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .ci .reactive.active{stroke-width:1.5}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .series text{fill:rgba(0,0,0,1)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .tooltip rect{fill:transparent;stroke:rgba(0,0,0,1);-webkit-transition:opacity 400ms ease-in;-moz-transition:opacity 400ms ease-in;transition:opacity 400ms ease-in}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .tooltip .value{font-size:1.5em}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .bound{font-size:.5em}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .map-element{fill:transparent;stroke:rgba(0,0,0,.54) !important}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .color-0,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .color-0 a:visited{stroke:red;fill:red}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .color-1,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .color-1 a:visited{stroke:#8299F7;fill:#8299F7}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .color-2,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .color-2 a:visited{stroke:#ED8223;fill:#ED8223}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .color-3,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .color-3 a:visited{stroke:purple;fill:purple}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .color-4,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .color-4 a:visited{stroke: ...
# #chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 text.no_data{text-anchor:middle}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .guide.line{fill:none}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .centered{text-anchor:middle}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .title{text-anchor:middle}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .legends .legend text{fill-opacity:1}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis.x text{text-anchor:middle}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis.y text{text-anchor:end}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis.y text[transform].backwards{text-anchor:start}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis.y2 text{text-anchor:start}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis.y2 text[transform].backwards{text-anchor:end}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis .guide.line{stroke-dasharray:4,4}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .axis .major.guide.line{stroke-dasharray:6,6}#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .horizontal .axis.y .guide.line,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .horizontal .axis.y2 .guide.line,#chart-e8f3680e-a952-4c25-b976-ab59c5c654b5 .vertical .axis.x .guide.line{opacity:0}#

# %%
custom_config = Config(width = 640,
                       height = 360,
                       explicit_size = True, 
                       style = custom_style, 
                       spacing = 50, 
                       margin_bottom = 100)

# %%
bar_chart = pygal.Bar(config = custom_config)

bar_chart.add('Dogs', 41)
bar_chart.add('Cats', 20)
bar_chart.add('Bird', 12)
bar_chart.add('Horses', 7)
bar_chart.add('Exotic Pets', 2)
bar_chart.add('No Pets', 18)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-e8e887ce-1250-4fbc-b947-bfe65a369ace" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2019-02-06--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .legends .legend text{font-family:arial;font-size:12px}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-e8e887ce-1250-4fbc-b947-bfe65a369ace{background-color:#ECF2F2}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace path,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace line,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace rect,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace circle{-webkit-transition:400ms ease-in;-moz-transition:400ms ease-in;transition:400ms ease-in}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .graph &gt; .background{fill:#ECF2F2}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .plot &gt; .background{fill:transparent}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .graph{fill:rgba(0,0,0,.87)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace text.no_data{fill:rgba(0,0,0,1)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .title{fill:rgba(0,0,0,1)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .legends .legend text{fill:rgba(0,0,0,.87)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis .line{stroke:rgba(0,0,0,1)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis text.major{fill:rgba(0,0,0,1)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis.y .guides:hover .guide.line,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .line-graph .axis.x .guides:hover .guide.line,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .stackedline-graph .axis.x .guides:hover .guide.line,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .reactive{fill-opacity:.6;stroke-opacity:.8}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .ci{stroke:rgba(0,0,0,.87)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .reactive.active,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .ci .reactive.active{stroke-width:1.5}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .series text{fill:rgba(0,0,0,1)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .tooltip rect{fill:transparent;stroke:rgba(0,0,0,1);-webkit-transition:opacity 400ms ease-in;-moz-transition:opacity 400ms ease-in;transition:opacity 400ms ease-in}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .tooltip .label{fill:rgba(0,0,0,.87)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .tooltip .label{fill:rgba(0,0,0,.87)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .tooltip .value{font-size:1.5em}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .bound{font-size:.5em}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .map-element{fill:transparent;stroke:rgba(0,0,0,.54) !important}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .color-0,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .color-0 a:visited{stroke:red;fill:red}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .color-1,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .color-1 a:visited{stroke:#8299F7;fill:#8299F7}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .color-2,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .color-2 a:visited{stroke:#ED8223;fill:#ED8223}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .color-3,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .color-3 a:visited{stroke:purple;fill:purple}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .color-4,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .color-4 a:visited{stroke: ...
# #chart-e8e887ce-1250-4fbc-b947-bfe65a369ace text.no_data{text-anchor:middle}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .guide.line{fill:none}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .centered{text-anchor:middle}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .title{text-anchor:middle}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .legends .legend text{fill-opacity:1}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis.x text{text-anchor:middle}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis.x:not(.web) text[transform]{text-anchor:start}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis.y text{text-anchor:end}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis.y text[transform].backwards{text-anchor:start}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis.y2 text{text-anchor:start}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis.y2 text[transform].backwards{text-anchor:end}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis .guide.line{stroke-dasharray:4,4}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .axis .major.guide.line{stroke-dasharray:6,6}#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .horizontal .axis.y .guide.line,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .horizontal .axis.y2 .guide.line,#chart-e8e887ce-1250-4fbc-b947-bfe65a369ace .vertical .axis.x .guide.line{opacity:0}#
